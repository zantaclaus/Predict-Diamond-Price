# %% [markdown]
# # **Import common Library and Dataset**

# %%
import pandas as pd                         # Import Pandas
import numpy as np                          # Import Numpy
data = pd.read_csv("cleanDiamods.csv")      # Import dataset

# %% [markdown]
#  # **Data Relationship**

# %%
data.corr()
# Out:
#             Unnamed: 0     carat       cut     color   clarity     depth  \
# Unnamed: 0    1.000000  0.548490 -0.048227 -0.089734 -0.044387 -0.032545
# carat         0.548490  1.000000  0.025462  0.032595  0.310484 -0.002382
# cut          -0.048227  0.025462  1.000000  0.006690  0.146362  0.212736
# color        -0.089734  0.032595  0.006690  1.000000 -0.192299  0.054654
# clarity      -0.044387  0.310484  0.146362 -0.192299  1.000000  0.084588
# depth        -0.032545 -0.002382  0.212736  0.054654  0.084588  1.000000
# table         0.005373  0.041602  0.413615 -0.025995  0.099773 -0.310199
# price         0.643612  0.861695 -0.087959 -0.142881 -0.016218 -0.057993
# x             0.547823  0.989917 -0.020181  0.021357  0.302476 -0.082729
# y             0.541836  0.988950 -0.013338  0.025267  0.291716 -0.086761
# z             0.537768  0.988016  0.023576  0.033498  0.313102  0.108071
#
#                table     price         x         y         z
# Unnamed: 0  0.005373  0.643612  0.547823  0.541836  0.537768
# carat       0.041602  0.861695  0.989917  0.988950  0.988016
# cut         0.413615 -0.087959 -0.020181 -0.013338  0.023576
# color      -0.025995 -0.142881  0.021357  0.025267  0.033498
# clarity     0.099773 -0.016218  0.302476  0.291716  0.313102
# depth      -0.310199 -0.057993 -0.082729 -0.086761  0.108071
# table       1.000000  0.003328  0.033938  0.021326 -0.031795
# price       0.003328  1.000000  0.862170  0.852105  0.844833
# x           0.033938  0.862170  1.000000  0.994908  0.980330
# y           0.021326  0.852105  0.994908  1.000000  0.979524
# z          -0.031795  0.844833  0.980330  0.979524  1.000000

# %% [markdown]
# # **Plot Graph**

# %%
import seaborn as sns               
import matplotlib.pyplot as plt

# %%
mask = np.triu(np.ones_like(data.corr()))
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, mask=mask)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(y="price", x="x",data=data)
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %%
sns.regplot(y="price", x="y",data=data)
# Out:
# <AxesSubplot:xlabel='y', ylabel='price'>

# %%
sns.regplot(y="price", x="z", data=data)
# Out:
# <AxesSubplot:xlabel='z', ylabel='price'>

# %%
sns.regplot(y="price", x="carat", data=data)
# sns.regplot(y="price", x="carat",data=data)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(y="price", x="depth", data=data)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
sns.regplot(y="price", x="table", data=data)
# Out:
# <AxesSubplot:xlabel='table', ylabel='price'>

# %%
sns.regplot(y="price", x="depth", data=data)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
sns.regplot(y="price", x="cut", data=data)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.regplot(y="price", x="color", data=data)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
sns.regplot(y="price", x="clarity", data=data)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>
