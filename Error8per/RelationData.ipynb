# %% [markdown]
# # **Import common Library and Dataset**

# %%
import pandas as pd                         # Import Pandas
import numpy as np                          # Import Numpy
data = pd.read_csv("cleanDiamods.csv")      # Import dataset

# %% [markdown]
#  # **Data Relationship**

# %%
data.drop(['Unnamed: 0'],axis=1,inplace=True)
data.corr()
# Out:
#             carat       cut     color   clarity     depth     table     price  \
# carat    1.000000  0.049582  0.074952  0.355949  0.016252  0.032659  0.747830
# cut      0.049582  1.000000 -0.006503  0.159045  0.221849  0.399029 -0.111005
# color    0.074952 -0.006503  1.000000 -0.163526  0.051920 -0.033861 -0.162964
# clarity  0.355949  0.159045 -0.163526  1.000000  0.091535  0.097027 -0.124267
# depth    0.016252  0.221849  0.051920  0.091535  1.000000 -0.324234 -0.057646
# table    0.032659  0.399029 -0.033861  0.097027 -0.324234  1.000000 -0.008267
# price    0.747830 -0.111005 -0.162964 -0.124267 -0.057646 -0.008267  1.000000
# x        0.987340 -0.006807  0.068171  0.339305 -0.082016  0.027399  0.759364
# y        0.986201  0.001672  0.071632  0.326861 -0.087250  0.011792  0.737978
# z        0.984408  0.049201  0.081010  0.352613  0.152262 -0.057083  0.730446
#
#                 x         y         z
# carat    0.987340  0.986201  0.984408
# ...

# %% [markdown]
# # **Plot Graph**

# %%
import seaborn as sns               
import matplotlib.pyplot as plt

# %%
mask = np.triu(np.ones_like(data.corr()))
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, mask=mask)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(y="price", x="x",data=data)
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %%
sns.regplot(y="price", x="y",data=data)
# Out:
# <AxesSubplot:xlabel='y', ylabel='price'>

# %%
sns.regplot(y="price", x="z", data=data)
# Out:
# <AxesSubplot:xlabel='z', ylabel='price'>

# %%
sns.regplot(y="price", x="carat", data=data)
# sns.regplot(y="price", x="carat",data=data)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(y="price", x="depth", data=data)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
sns.regplot(y="price", x="table", data=data)
# Out:
# <AxesSubplot:xlabel='table', ylabel='price'>

# %%
sns.regplot(y="price", x="depth", data=data)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
sns.regplot(y="price", x="cut", data=data)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.regplot(y="price", x="color", data=data)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
sns.regplot(y="price", x="clarity", data=data)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>
