# %% [markdown]
# # **Import common Library and Dataset**

# %%
import pandas as pd                         # Import Pandas
import numpy as np                          # Import Numpy
data = pd.read_csv("cleanDiamods.csv")      # Import dataset

# %% [markdown]
#  # **Data Relationship**

# %%
data.corr()
# Out:
#             Unnamed: 0     carat       cut     color   clarity     depth  \
# Unnamed: 0    1.000000 -0.377983 -0.096492 -0.095098 -0.207348 -0.034800
# carat        -0.377983  1.000000  0.134967  0.291437  0.355074  0.028224
# cut          -0.096492  0.134967  1.000000  0.020519  0.192692  0.218055
# color        -0.095098  0.291437  0.020519  1.000000 -0.023079  0.047279
# clarity      -0.207348  0.355074  0.192692 -0.023079  1.000000  0.071840
# depth        -0.034800  0.028224  0.218055  0.047279  0.071840  1.000000
# table        -0.100830  0.181618  0.433405  0.026465  0.160630 -0.295779
# price        -0.306873  0.921591  0.053491  0.172511  0.144217 -0.010647
# x            -0.405440  0.975094  0.125565  0.270287  0.373021 -0.025289
# y            -0.395843  0.951722  0.121462  0.263584  0.359150 -0.029341
# z            -0.399208  0.953387  0.149323  0.268227  0.368309  0.094924
#
#                table     price         x         y         z
# Unnamed: 0 -0.100830 -0.306873 -0.405440 -0.395843 -0.399208
# carat       0.181618  0.921591  0.975094  0.951722  0.953387
# cut         0.433405  0.053491  0.125565  0.121462  0.149323
# color       0.026465  0.172511  0.270287  0.263584  0.268227
# clarity     0.160630  0.144217  0.373021  0.359150  0.368309
# depth      -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table       1.000000  0.127134  0.195344  0.183760  0.150929
# price       0.127134  1.000000  0.884435  0.865421  0.861249
# x           0.195344  0.884435  1.000000  0.974701  0.970772
# y           0.183760  0.865421  0.974701  1.000000  0.952006
# z           0.150929  0.861249  0.970772  0.952006  1.000000

# %% [markdown]
# # **Plot Graph**

# %%
import seaborn as sns               
import matplotlib.pyplot as plt

# %%
mask = np.triu(np.ones_like(data.corr()))
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, mask=mask)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(y="price", x="x",data=data)
# Out:
# <AxesSubplot:xlabel='x', ylabel='price'>

# %%
sns.regplot(y="price", x="y",data=data)
# Out:
# <AxesSubplot:xlabel='y', ylabel='price'>

# %%
sns.regplot(y="price", x="z", data=data)
# Out:
# <AxesSubplot:xlabel='z', ylabel='price'>

# %%
sns.regplot(y="price", x="carat", data=data)
# sns.regplot(y="price", x="carat",data=data)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.regplot(y="price", x="depth", data=data)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
sns.regplot(y="price", x="table", data=data)
# Out:
# <AxesSubplot:xlabel='table', ylabel='price'>

# %%
sns.regplot(y="price", x="depth", data=data)
# Out:
# <AxesSubplot:xlabel='depth', ylabel='price'>

# %%
sns.regplot(y="price", x="cut", data=data)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.regplot(y="price", x="color", data=data)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
sns.regplot(y="price", x="clarity", data=data)
# Out:
# <AxesSubplot:xlabel='clarity', ylabel='price'>
